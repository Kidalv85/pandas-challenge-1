# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
df = pd.read_csv('Resources/client_dataset.csv')
df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
df.tail()
# Out:
#          first       last                      job               phone  \
# 54634   Lauren      Reese           Radio producer  977.877.5272x11382
# 54635  Derrick      Moore                 Musician        358.661.5483
# 54636   Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637    Wanda    Solomon             Toxicologist       (311)767-4924
# 54638   Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                     email  client_id  order_id  order_date  \
# 54634  late_reese_4081@montoya-chavez.org      29043   9021716  2023-04-26
# 54635        derrick.moore.2602@pope.info      41908   6290153  2023-02-08
# 54636           gutierrezm3195@morris.org      35176   8692622  2023-03-05
# 54637           solomonwanda5962@ross.org      24485   7592730  2023-01-18
# 54638                    belld@galvan.com      24007   7489403  2023-01-04
#
#        order_week  order_year         item_id     category  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe(include='all')
# Out:
#               first     last        job       phone                     email  \
# count         54639    54639      54639       54639                     54639
# unique          360      477        498         999                       999
# top     Christopher  Johnson  Osteopath  5016915923  jessica.reyes@grimes.net
# freq           1090     1164        631         220                       220
# mean            NaN      NaN        NaN         NaN                       NaN
# std             NaN      NaN        NaN         NaN                       NaN
# min             NaN      NaN        NaN         NaN                       NaN
# 25%             NaN      NaN        NaN         NaN                       NaN
# 50%             NaN      NaN        NaN         NaN                       NaN
# 75%             NaN      NaN        NaN         NaN                       NaN
# max             NaN      NaN        NaN         NaN                       NaN
#
# ...

# %%
# Use the describe function to gather some basic statistics
df['first'].describe()
# Out:
# count           54639
# unique            360
# top       Christopher
# freq             1090
# Name: first, dtype: object

# %%
# Checking if df has any NaN values
df.isna().sum()
# Out:
# first          0
# last           0
# job            0
# phone          0
# email          0
# client_id      0
# order_id       0
# order_date     0
# order_week     0
# order_year     0
# item_id        0
# category       0
# subcategory    0
# unit_price     0
# unit_cost      0
# unit_weight    0
# qty            0
# line_number    0
# dtype: int64

# %%
# Checking if df has any NaN values
df.isnull().sum()
# Out:
# first          0
# last           0
# job            0
# phone          0
# email          0
# client_id      0
# order_id       0
# order_date     0
# order_week     0
# order_year     0
# item_id        0
# category       0
# subcategory    0
# unit_price     0
# unit_cost      0
# unit_weight    0
# qty            0
# line_number    0
# dtype: int64

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
# get types
df.dtypes
# Out:
# first           object
# last            object
# job             object
# phone           object
# email           object
# client_id        int64
# order_id         int64
# order_date      object
# order_week       int64
# order_year       int64
# item_id         object
# category        object
# subcategory     object
# unit_price     float64
# unit_cost      float64
# unit_weight    float64
# qty              int64
# line_number      int64
# dtype: object

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
# get shape
df.shape
# Out:
# (54639, 18)

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
# getting counts off some names 
df.head()
df['first'].value_counts()
# Out:
# first
# Christopher    1090
# Michael        1047
# William         982
# John            959
# Jennifer        902
# Daniel          791
# Thomas          772
# David           742
# Jessica         730
# Michelle        656
# Brian           602
# Melissa         598
# Ashley          586
# James           571
# Robert          556
# Mary            551
# Richard         548
# Brandon         526
# Mark            522
# Nicholas        502
# Lisa            499
# Lori            485
# Nicole          467
# Patrick         456
# Sarah           453
# Katie           404
# Rebecca         403
# Angela          395
# Bryan           392
# Julie           389
# Anthony         389
# Susan           382
# Sara            355
# Holly           346
# Wendy           341
# Sean            339
# Peter           338
# Alexandra       332
# Joseph          329
# Matthew         328
# Danny           324
# Doris           321
# Elizabeth       320
# Charles         316
# Heather         313
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
# get emails of the first 3 rows

df.iloc[0:3,4]
# Out:
# 0     harding.donald.7185@sullivan.com
# 1    myers.t.6537@ferguson-johnson.net
# 2                swatson8146@payne.net
# Name: email, dtype: object

# %%
# What three item categories had the most entries?
# Select the top three categories
# option 1
category_counts = df['category'].value_counts()
top_three_categories = category_counts.head(3)
top_three_categories
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries,
# which subcategory had the most entries?
# Select the top category
top_category = df['category'].value_counts().idxmax()
# Filter the DataFrame to include only the rows with the top category
top_category_df = df[df['category'] == top_category]
# Use value_counts() on the subcategory column within the filtered DataFrame
subcategory_counts = top_category_df['subcategory'].value_counts()
top_subcategory = subcategory_counts.head(1)
top_subcategory
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
top_clients_counts = df['client_id'].value_counts()
top_five_clients = top_clients_counts.head(5)
print(top_five_clients)
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
cliants_as_list = list(top_five_clients.to_dict().keys())
print(cliants_as_list)
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the
# client with the most entries order order?

top_client = df['client_id'].value_counts().idxmax()
print(top_client)
top_client_df = df[df['client_id'] == top_client]
top_client_df['qty'].sum()
# Out:
# 33615
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the 
# subtotal for each line using the unit_price
# and the qty
updated_df = df.copy()
updated_df['subtotal'] = updated_df['unit_price'] * updated_df['qty']
updated_df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.
def calculate_shipping_cost(weight,qty):
    total_weight = weight*qty
    if total_weight > 50:
        return 7 * total_weight
    else: return 10 * total_weight

updated_df['shipping_price'] = updated_df.apply(lambda row  : calculate_shipping_cost(row['unit_weight'],row['qty']),axis=1)
updated_df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%
# 125898.61
# 125898.607500
sum = updated_df['subtotal'] + updated_df['shipping_price']
updated_df['total_price'] = (sum + sum * 0.0925).round(2)
updated_df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...     category         subcategory unit_price  \
# ...

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).
updated_df['cost'] = (updated_df['qty'] * updated_df['unit_cost']) + updated_df['shipping_price']
updated_df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...         subcategory unit_price unit_cost  \
# ...

# %%
# Create a column for the profit of
# each line using line cost and line price
updated_df['profit'] = updated_df['total_price'] - updated_df['cost']
updated_df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_price unit_cost unit_weight  qty  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
# Order 2742071 total: $152811.89
specific_order_1 = 2742071

# Filter the DataFrame based on the specific order ID
filtered_df_1 = updated_df[updated_df['order_id'] == specific_order_1]


selected_columns = filtered_df_1.loc[:, ['order_id', 'total_price']].groupby('order_id')['total_price'].sum()
print(selected_columns)
# Out:
# order_id
# 2742071    152811.89
# Name: total_price, dtype: float64

# %%
# Check your work using the totals above
# Order 2173913 total: $162388.71
specific_order_2 = 2173913

# Filter the DataFrame based on the specific order ID
filtered_df_2 = updated_df[updated_df['order_id'] == specific_order_2]

selected_columns_2 = filtered_df_2.loc[:, ['order_id', 'total_price']].groupby('order_id')['total_price'].sum()
print(selected_columns_2)
# Out:
# order_id
# 2173913    162388.71
# Name: total_price, dtype: float64

# %%
# Check your work using the totals above
# Order 2173913 total: $923441.25
specific_order_3 = 6128929

# Filter the DataFrame based on the specific order ID
filtered_df_3 = updated_df[updated_df['order_id'] == specific_order_3]

selected_columns_3 = filtered_df_3.loc[:, ['order_id', 'total_price']].groupby('order_id')['total_price'].sum()
print(selected_columns_3)
# Out:
# order_id
# 6128929    923441.25
# Name: total_price, dtype: float64

# %%
# Display all 3 reciepts at once
compined_reciept = updated_df.groupby('order_id')['total_price'].sum()
compined_reciept_details = {
    specific_order_1 : format(compined_reciept.loc[specific_order_1], ',.2f') ,
    specific_order_2 : format(compined_reciept.loc[specific_order_2], ',.2f') ,
    specific_order_3 : format(compined_reciept.loc[specific_order_3], ',.2f') 
}
for order,total in compined_reciept_details.items():
    print(f"Order ID {order} had a total price of " + f"${total}")
# Out:
# Order ID 2742071 had a total price of $152,811.89
# Order ID 2173913 had a total price of $162,388.71
# Order ID 6128929 had a total price of $923,441.25

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.

total_spending_top_clients = {}

# Calculate total spending for each of the top 5 clients by quantity
for client_id, total_quantity in top_five_clients.items():
    client_df = updated_df[updated_df['client_id'] == client_id]
    total_spending = client_df['total_price'].sum()
    total_spending_top_clients[client_id] = format(total_spending,'.2f')

for client_id, total_spending in total_spending_top_clients.items():
    print(f"{client_id}: $" + f"{total_spending}")
# Out:
# 33615: $8377308.52
# 66037: $10259514.79
# 46820: $9743794.36
# 38378: $12906550.87
# 24741: $82268892.02

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.

# %%
# Format the data and rename the columns
# to names suitable for presentation.
# Currency should be in millions of dollars.

# %%
# Sort the updated data by "Total Profit" form highest to lowest
